# %% [markdown]
# # 클라우드 교육
#
# #### 클라우드 컴퓨팅이란
#
# - 컴퓨팅
# - 네트워킹
# - 스토리지
# - 분석
#
# ##### 특징
#
# - 고가용성
# - 내결함성 Fault Tolerence
# - 확장성
# - 탄력성 Auto scaling
# - 글로벌한 범위
# - 고객 대기 시간 기능
# - 예측 비용 고려 사항 (ML로 예측이 가능해짐)
# - 민첩성
# - 보안
# - 재해 복구
#
# #### 추가 특징
#
# - CapEx 자본 지출, 시간이 지날수록 가치가 낮아짐
# - OpEx 운영 비용, 필요에 따라 즉시 청구됨
# - 소비 기반 모델, 사용하는 리소스에 대해서만 비용을 지불
#
# ### Private Cloud
#
# - 조직의 데이터센터에서 클라우드 환경 구축
# - 운영을 조직이 담당
# - 외부 엑세스 불가
#
# # IaaS
#
# #### infrastructure as a service
#
# 가장 유연한 클라우드 서비스
# 고객이 하드웨어를 구성하고 관리
#
# # PaaS
#
# 기본 인프라 관리에 집중하지 않으면서 애플리케이션을 빌드, 테스트 배포할 수 있는 환경 제공
#
# # SaaS
#
# 호스팅된 응용 프로그램 / 앱
# 결제만 하면됨
#
# ## Azure 펀더멘탈

# %% [markdown]
# ### 서비스와 리소스
#
# - 서비스 (메뉴판)
#   - 요구하는 스키마, 설계도
# - 리소스
#
# # Azure 글로벌 인프라 용어
#
# - 지오그래피 (한국)
#   - Region Pairs (서울, 부산)
#     - Regions
#       - Zones
#         - 데이터 센터 다수
#           - 서버들

# %% [markdown]
# ## 리소스 그룹 만들기
#
# ## 리소스 만들기
#
# ## 퍼블릭 ip 만들기
#
# ## 리소스 그룹
#
# - 리소스는 한 리소스 그룹에만 존재
# - Rule base access control 룰 기반 접근 제어
# - 프로젝트 진행중에는 삭제 잠금, 배포시에는 읽기 전용
#
# ## Microsoft Entra ID
#
# - 엔드라 아이디 서비스로 생성한 인스턴스 -> 테넌트(관리자 유저들)
# - 자동생성
# - 서로다른 테넌트는 접근 못함 초대를 해줘야함
#
# ## Infra as a code

# %% [markdown]
# # 사용자 계정 만들기
#
# ### 그룹을 만들어서 권한을 부여한다.
#
# 유저마다 고유한 id가 있어야함 -> 메일 주소처럼 생김 -> 내부유저인지 외부유저인지 확인가능
#
# ## azure는 롤베이스 AC 이 두가지가 있다.
#
# entra id RBAC tanent 안에도 엑세스 제어가 있고
# azure RBAC

# %% [markdown]
# # 새 사용자 만들기
#
# # 그룹 계정 만들기
#
# - 보안 그룹 -> 권한 부여 가능
# - miicrosoft 365 그룹
#
# # 멤머 자격 유형
#
# - 할당됨
# - 동적 사용자
# - 동적 디바이스
#
# # Azure RBAC
#
# 1. 허용 또는 거부 작업 정의
# 2. 사용자나 그룹, 서비스 주체와 역할 연결
# 3. 구독이나 리소스 그룹, 특정 리소스에 대한 범위 설정
#
# # 가상 네트워크 개요
#
# - 물리적인 네트워크의 논리적 표현
# - 격리된 프라이빗 네트워크 제공
# - VNet을 사용한 안전한 데이터 센터 확장
# - 하이브리드 클라우드 시나리오
#
# # 가상 네트워크 설계
#
# - 주소할당 : 정적 할당과 동적 할당
#
# # 서브넷 설계
#
# - 장점
#   - 네트워크 성능 향상
#   - 네트워크 정체 감소
#   - 네트워크 보안 향상
#   - 적절한 네트워크 크기 유지
#   - 관리 용이

# %% [markdown]
# ##### 서브넷 마스크 쓰는 이유
#
# - 네트워크 주소와 호스트 주소를 나눌때 사용
#
# #### 서브넷의 예약된 주소
#
# - x.x.x.0 : 네트워크 주소
# - x.x.x.1 : Azure에서 기본 게이트웨이로 예약
# - x.x.x.2, x.x.x.3 Azure DNS ip를 VNet 공간에 매핑하기 위해 예약
# - x.x.x.255 : 네트워크 브로드캐스트 주소

# %% [markdown]
# ##### 로드 밸런서가 여러 프런트에 가는 길을 부하분산해줌 <- public IP(DNS가 이름-> IP) 부여 요기에 함
#
# ##### Gateway
#
# `on prem과 public cloud를 vpn으로 직접연결`
#
# ##### application gateway
#
# `L7에서의 로드밸런서`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 가상 머신 배포 고려사항
#
# - 가상 머신 이름용 호스트 이름
# - 배포 위치와 비용
#
# #### Azure 서비스의 리소스 생성 모델
#
# 1. 하위 리소스 (원시 부품)
# 2. 상위 리소스 (모듈)
# 3. 서비듈 (최종 제품)
#
# #### 에저 가상 머신 구성 요소
#
# 1. 운영 체제
# 2. 네트워킹 요소
# 3. 가상 머신 크기
# 4. 가상 디스크

# %% [markdown]
# GiB != GB 기비바이트(1024로 계산함)
# TiB != TB
# KiB != kB

# %% [markdown]
# - 사용자 이름 tony
# - 암호 123654789123!a
# - 퍼블릭 프론트 74.**_._**.51
# - 프라이빗 백엔드 10.**_.42._**
#
# #웹 서버(IIS) 역할 설치
# Install-WindowsFeature -Name Web-Server -IncludeManagementTools
#
# #Default.html 만들기
# Set-Content -Path "C:\inetpub\wwwroot\Default.htm" -Value "Running Jarvis built on Copilot from host $($env:computername) !"
#
# dickmgmt.msc 디스크 관리도구

# %% [markdown]
# ### Azure 스토리지 개요
#
# #### 데이터 유형
#
# 1. 비정형 데이터 ex. 사진, 영상, 오오오
# 2. 반정형 데이터 (반구조적 ) 연산 불가 ex. json, xml
# 3. 정형 데이터 ex. sql
#
# #### Azure 스토리지의 지원 시나리오
#
# 1. 가상 머신의 디스크 저장소
# 2. 공유 폴더용 저장소
# 3. 정의된 데이터 모델이 없는 데이터의 저장소
# 4. 스키마 구조를 따르는 관계형 데이터의 저장소
# 5. 데이터별 스키마 구조를 갖는 반 구조화된 데이터의 저장소

# %% [markdown]
# smb : IBM에서 만든 프로토콜

# %% [markdown]
# Azure 리소스 그룹
#
# - 컨테이너
#   - blob
#     - 이미지
#     - 문서
#     - 로그
#     - 데이터베이스
# - 테이블
#   - 엔티티
#     - Name
#     - Email

# %% [markdown]
# ## 파일 공유 서비스
#
# 주요 시나리오
#
# 1. 파일 서버 사용 온프레미스 어플리케이션 마이그레이션
# 2. 구성파일 및 도구, 유틸리티 공유
# 3. 로그 및 충돌 덤프 등을 저장한 후 분석
# 4. 컨테이너 영구 저장소

# %% [markdown]
# ## 컨테이너 스토리지 서비스
#
# ### Blob Storage
#
# 클라우드에 구조화되지 않은 데이터를 저장하는 개체 스토리지입니다.
#
# #### 용도
#
# - 직접 이미지 또는 문서 제공
# - 분산 엑세스용 파일 저장
# - 비디오 오디오 스트리밍
# - 백업, 복원, 재해복구
# - 분석 데이터 저장
#
# #### 블롭의 유형
#
# - **Blob**: 일반적인 파일 저장
# - **Page Blob**: 읽기/쓰기 위치를 정밀하게 지정해 자주 변경되는 데이터 저장
# - **Append Blob**: 계속 누적되는 기록 저장
#
# #### 블롭의 계층
#
# - 핫계층 : 자주 엑세스하거나 수정되는 데이터
# - 쿨계층 : 드물게 엑세스되고 최소 30일 동안 저장되는 데이터에 최적화
# - 콜드계층 : 90일 이상 드물게 엑세스되거나 또는 수정 및 저장되지 않는 데이터
# - 보관 : 검색 대기 시간에 몇 시간 이상씩 걸리며, 최소 180일 이상 보관 계층에 저장되는 데이터

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Azure App 서비스 개요
#
# 1. HTTP 기반 서비스
#    1. 웹 애플리케이션, rest api, 모바일 백엔드
# 2. Windows 및 리눅스 환경 지원
# 3. Microsoft Azure의 강력한 기능
# 4. DevOps 기능 활용
#    1. Azure devops, github, docker hub
# 5. App 서비스 계획을 통한 컴퓨팅 리소스
#
# ### App 서비스의 주요 기능
#
# 1. 다양한언어와런타임스택
# 2. 관리형프러덕션환경
# 3. 컨테이너화및도커
# 4. DevOps 최적화
# 5. 고가용성? 및 글로벌 규모 실행
# 6. SaaS 플랫폼과온-프레미스데이터연결
# 7. 보안과규정준수
# 8. 애플리케이션템플릿
# 9. Visual Studio 와 Visual Studio Code 통합
# 10. API 및 모바일 기능
# 11. 서버리스코드（정적웹앱）
#
# ### App 서비스 요금제 계획
#
# - 구독, 지역, 리소스 그룹, 가격 계층, 인스턴스 크기, 개수
